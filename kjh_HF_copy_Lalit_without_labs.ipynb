# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data_comorbid_nolabs.csv')
df.head()
# Out:
#    group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0      1  125047      0.0   72        1  37.588179             0
# 1      1  139812      0.0   75        2        NaN             0
# 2      1  109787      0.0   83        2  26.572634             0
# 3      1  130587      0.0   43        2  83.264629             0
# 4      1  138290      0.0   75        2  31.824842             1
#
#    atrialfibrillation  CHD with no MI  diabetes  ...  Renal failure  COPD  \
# 0                   0               0         1  ...              1     0
# 1                   0               0         0  ...              0     1
# 2                   0               0         0  ...              1     0
# 3                   0               0         0  ...              0     0
# 4                   0               0         0  ...              1     1
#
#    comorbidities  heart rate  Systolic blood pressure  \
# 0              4   68.837838               155.866667
# ...

# %%
df.describe()
# Out:
#              group             ID      outcome          age      gendera  \
# count  1177.000000    1177.000000  1176.000000  1177.000000  1177.000000
# mean      1.299065  150778.120646     0.135204    74.055225     1.525064
# std       0.458043   29034.669513     0.342087    13.434061     0.499584
# min       1.000000  100213.000000     0.000000    19.000000     1.000000
# 25%       1.000000  125603.000000     0.000000    65.000000     1.000000
# 50%       1.000000  151901.000000     0.000000    77.000000     2.000000
# 75%       2.000000  176048.000000     0.000000    85.000000     2.000000
# max       2.000000  199952.000000     1.000000    99.000000     2.000000
#
#               BMI  hypertensive  atrialfibrillation  CHD with no MI  \
# count  962.000000   1177.000000         1177.000000     1177.000000
# mean    30.188278      0.717927            0.451147        0.085811
# std      9.325997      0.450200            0.497819        0.280204
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   group                     1177 non-null   int64
#  1   ID                        1177 non-null   int64
#  2   outcome                   1176 non-null   float64
#  3   age                       1177 non-null   int64
#  4   gendera                   1177 non-null   int64
#  5   BMI                       962 non-null    float64
#  6   hypertensive              1177 non-null   int64
#  7   atrialfibrillation        1177 non-null   int64
#  8   CHD with no MI            1177 non-null   int64
#  9   diabetes                  1177 non-null   int64
#  10  deficiencyanemias         1177 non-null   int64
#  11  depression                1177 non-null   int64
#  12  Hyperlipemia              1177 non-null   int64
#  13  Renal failure             1177 non-null   int64
# ...

# %%
df_dropna=df.dropna()

# %%
df_dropna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 948 entries, 0 to 1176
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   group                     948 non-null    int64
#  1   ID                        948 non-null    int64
#  2   outcome                   948 non-null    float64
#  3   age                       948 non-null    int64
#  4   gendera                   948 non-null    int64
#  5   BMI                       948 non-null    float64
#  6   hypertensive              948 non-null    int64
#  7   atrialfibrillation        948 non-null    int64
#  8   CHD with no MI            948 non-null    int64
#  9   diabetes                  948 non-null    int64
#  10  deficiencyanemias         948 non-null    int64
#  11  depression                948 non-null    int64
#  12  Hyperlipemia              948 non-null    int64
#  13  Renal failure             948 non-null    int64
# ...

# %%
df_dropna.corr()
# Out:
#                              group        ID   outcome       age   gendera  \
# group                     1.000000  0.001533 -0.008573 -0.022426  0.004529
# ID                        0.001533  1.000000  0.022735 -0.040431 -0.017286
# outcome                  -0.008573  0.022735  1.000000  0.081439 -0.013648
# age                      -0.022426 -0.040431  0.081439  1.000000  0.077089
# gendera                   0.004529 -0.017286 -0.013648  0.077089  1.000000
# BMI                      -0.037936  0.044994 -0.062366 -0.381656  0.023866
# hypertensive             -0.077421  0.005541 -0.044686  0.196943  0.013641
# atrialfibrillation        0.008542 -0.028753  0.084783  0.295468 -0.022150
# CHD with no MI            0.036778  0.023221  0.004017  0.053547 -0.090020
# diabetes                  0.036891  0.016433 -0.034331 -0.076166 -0.045436
# deficiencyanemias         0.000594 -0.007490 -0.118024 -0.004983  0.046010
# ...

# %%
#correlation between demographics and outcome
col1 = ['outcome', 'age', 'gendera', 'BMI']
corr1 = df_dropna[col1].corr()
corr1
# Out:
#           outcome       age   gendera       BMI
# outcome  1.000000  0.081439 -0.013648 -0.062366
# age      0.081439  1.000000  0.077089 -0.381656
# gendera -0.013648  0.077089  1.000000  0.023866
# BMI     -0.062366 -0.381656  0.023866  1.000000

# %%
# Use color themes for the project
mypalette = ['#aaaaaa', '#60abae','#9fccce','#b7d251','#ffffff']
# Set custom color palette
sns.set_palette(sns.color_palette(mypalette))

# %%
col = ['hypertensive','atrialfibrillation', 'CHD with no MI', 'diabetes', 'deficiencyanemias',
       'depression', 'Hyperlipemia', 'Renal failure', 'COPD', 'outcome']

# %%
#correlation between different comorbidities
corr = df_dropna[col].corr()
corr
# Out:
#                     hypertensive  atrialfibrillation  CHD with no MI  \
# hypertensive            1.000000            0.010817        0.015212
# atrialfibrillation      0.010817            1.000000        0.008462
# CHD with no MI          0.015212            0.008462        1.000000
# diabetes                0.138671            0.000108        0.005419
# deficiencyanemias       0.020465           -0.097772        0.053132
# depression             -0.055668           -0.048414        0.030097
# Hyperlipemia            0.214668            0.068700        0.053526
# Renal failure           0.207347            0.055161        0.031609
# COPD                    0.021968           -0.021005        0.001517
# outcome                -0.044686            0.084783        0.004017
#
#                     diabetes  deficiencyanemias  depression  Hyperlipemia  \
# hypertensive        0.138671           0.020465   -0.055668      0.214668
# ...

# %%
# Use color themes for the project
mypalette = ['#aaaaaa', '#60abae','#9fccce','#b7d251','#ffffff']
# Set custom color palette
sns.set_palette(sns.color_palette(mypalette))

# %%
# correlation heatmap between different comorbidities
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap=mypalette, linewidths=0.01, linecolor="white");

# %%
# combining comorbidities into one column
df_dropna['Comorbidities'] = df_dropna[col].sum(axis=1)
df_dropna.head()
# Out:
# C:\Users\Range\AppData\Local\Temp/ipykernel_14040/3694266096.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dropna['Comorbidities'] = df_dropna[col].sum(axis=1)
#    group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0      1  125047      0.0   72        1  37.588179             0
# 2      1  109787      0.0   83        2  26.572634             0
# 3      1  130587      0.0   43        2  83.264629             0
# 4      1  138290      0.0   75        2  31.824842             1
# 5      1  154653      0.0   76        1  24.262293             1
#
#    atrialfibrillation  CHD with no MI  diabetes  ...  COPD  comorbidities  \
# 0                   0               0         1  ...     0              4
# ...

# %%
#correlation between number of comorbidities and outcome
df_dropna[['Comorbidities', 'outcome']].corr()
# Out:
#                Comorbidities  outcome
# Comorbidities        1.00000  0.11492
# outcome              0.11492  1.00000

# %%
#correlation between demographics and outcome
col1 = ['outcome', 'age', 'gendera', 'BMI']
corr1 = df_dropna[col1].corr()
corr1
# Out:
#           outcome       age   gendera       BMI
# outcome  1.000000  0.081439 -0.013648 -0.062366
# age      0.081439  1.000000  0.077089 -0.381656
# gendera -0.013648  0.077089  1.000000  0.023866
# BMI     -0.062366 -0.381656  0.023866  1.000000

# %%
# correlation heatmap between demographics and outcome
plt.figure(figsize=(12,8))
sns.heatmap(corr1, annot=True, cmap=mypalette, linewidths=0.01, linecolor="white");

# %%
#scatter plot
sns.relplot(x='BMI', y='age', hue='outcome', data=df)

# %%
import pandas as pd
import numpy as np

# %%
#import/read data
df = pd.read_csv('Capstone_dataset.csv')
df.head()
# Out:
#    group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0      1  125047      0.0   72        1  37.588179             0
# 1      1  139812      0.0   75        2        NaN             0
# 2      1  109787      0.0   83        2  26.572634             0
# 3      1  130587      0.0   43        2  83.264629             0
# 4      1  138290      0.0   75        2  31.824842             1
#
#    atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 0                   0               0         1  ...    138.750000
# 1                   0               0         0  ...    138.888889
# 2                   0               0         0  ...    140.714286
# 3                   0               0         0  ...    138.500000
# 4                   0               0         0  ...    136.666667
#
#    Blood calcium    Chloride  Anion gap  Magnesium ion     PH  Bicarbonate  \
# 0       7.463636  109.166667  13.166667       2.618182  7.230    21.166667
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   group                     1177 non-null   int64
#  1   ID                        1177 non-null   int64
#  2   outcome                   1176 non-null   float64
#  3   age                       1177 non-null   int64
#  4   gendera                   1177 non-null   int64
#  5   BMI                       962 non-null    float64
#  6   hypertensive              1177 non-null   int64
#  7   atrialfibrillation        1177 non-null   int64
#  8   CHD with no MI            1177 non-null   int64
#  9   diabetes                  1177 non-null   int64
#  10  deficiencyanemias         1177 non-null   int64
#  11  depression                1177 non-null   int64
#  12  Hyperlipemia              1177 non-null   int64
#  13  Renal failure             1177 non-null   int64
# ...

# %%
# Dropped the first three columns
df.drop(["ID","group","outcome"], inplace=True, axis=1)

# %%
df.head(600)
# Out:
#      age  gendera        BMI  hypertensive  atrialfibrillation  \
# 0     72        1  37.588179             0                   0
# 1     75        2        NaN             0                   0
# 2     83        2  26.572634             0                   0
# 3     43        2  83.264629             0                   0
# 4     75        2  31.824842             1                   0
# ..   ...      ...        ...           ...                 ...
# 595   62        1  31.869388             0                   1
# 596   79        2  28.492704             1                   1
# 597   83        2        NaN             0                   0
# 598   64        2  52.721194             1                   0
# 599   88        1  27.774271             1                   1
#
#      CHD with no MI  diabetes  deficiencyanemias  depression  Hyperlipemia  \
# 0                 0         1                  1           0             1
# ...

# %%
df.groupby("age")[["BMI", "hypertensive", "atrialfibrillation", "CHD with no MI", "diabetes"]].mean()
# Out:
#             BMI  hypertensive  atrialfibrillation  CHD with no MI  diabetes
# age
# 19    29.788969           0.0                 0.0             0.0      0.00
# 25    57.926531           0.0                 0.0             0.0      0.00
# 28   104.970366           0.0                 0.0             0.0      0.00
# 32    25.564954           1.0                 0.0             0.0      1.00
# 35    30.728379           0.5                 0.0             0.0      0.25
# ..          ...           ...                 ...             ...       ...
# 95    23.344651           0.0                 1.0             0.0      0.00
# 96    24.971075           0.8                 0.8             0.0      0.40
# 97    22.259141           1.0                 1.0             0.0      0.00
# 98    45.447280           1.0                 0.0             0.0      1.00
# 99    23.306980           0.0                 1.0             0.0      1.00
#
# [68 rows x 5 columns]

# %%
# number of occurances (Male=1 & Females=2)
df['gendera'].value_counts()
# Out:
# 2    618
# 1    559
# Name: gendera, dtype: int64

# %%
#Relative Frequencies of gender values
df['gendera'].value_counts(normalize = True)
# Out:
# 2    0.525064
# 1    0.474936
# Name: gendera, dtype: float64

# %%
df[["diabetes", "hypertensive"]].groupby(["diabetes", "hypertensive"]).size()
# Out:
# diabetes  hypertensive
# 0         0               226
#           1               455
# 1         0               106
#           1               390
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine, inspect

# %%
data = "capstone_dataset.csv"
df = pd.read_csv(data)
df.head()
# Out:
#    group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0      1  125047        0   72        1  37.588179             0
# 1      1  139812        0   75        2  30.188278             0
# 2      1  109787        0   83        2  26.572634             0
# 3      1  130587        0   43        2  83.264629             0
# 4      1  138290        0   75        2  31.824842             1
#
#    atrialfibrillation  CHD with no MI  diabetes  ...  Blood calcium  \
# 0                   0               0         1  ...       7.463636
# 1                   0               0         0  ...       8.162500
# 2                   0               0         0  ...       8.266667
# 3                   0               0         0  ...       9.476923
# 4                   0               0         0  ...       8.733333
#
#      Chloride  Anion gap  Magnesium ion     PH  Bicarbonate  Lactic acid  \
# 0  109.166667  13.166667       2.618182  7.230    21.166667          0.5
# ...

# %%
database_path = "capstone_dataset.sqlite"
conn_string = f"sqlite:///{database_path}"

# %%
#Create an engine that can talk to the database
engine = create_engine(conn_string)

# %%
sql = """CREATE TABLE patient ( ID pk,
    gendera  int,fk,
    age int, BMI varchar(4)
)"""

# %%
inspector_gadget = inspect(engine)
tables = inspector_gadget.get_table_names()
for table in tables:
    print(tables)

# %%
patientInfo_df = pd.DataFrame()
patientInfo_df['ID'] = [125047, 139812, 109787, 130587, 138297]
patientInfo_df['Gender'] = [1,2,2,2,2]
patientInfo_df['Age'] = [72,75,83,43,75]
patientInfo_df['BMI'] = [37.5,30.2,26.6,83.3,31.8]
patientInfo_df
# Out:
#        ID  Gender  Age   BMI
# 0  125047       1   72  37.5
# 1  139812       2   75  30.2
# 2  109787       2   83  26.6
# 3  130587       2   43  83.3
# 4  138297       2   75  31.8

# %%
bloodPressure_df = pd.DataFrame()
bloodPressure_df['ID'] = [125047, 139812, 109787, 130587, 138297]
bloodPressure_df
# Out:
#        ID
# 0  125047
# 1  139812
# 2  109787
# 3  130587
# 4  138297
